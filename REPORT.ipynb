# %% [markdown]
# <a href="https://colab.research.google.com/github/Ha-Hien/DBA/blob/main/REPORT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: 10 random numbers using numpy

import numpy as np

random_numbers = np.random.rand(10)
random_numbers
# Out:
# array([0.49342994, 0.25535295, 0.54496899, 0.75628277, 0.02966272,
#        0.31630551, 0.15051841, 0.79569293, 0.68205871, 0.47701371])

# %%
# !git clone https://github.com/Ha-Hien/DBA.git
# Out:
# Cloning into 'DBA'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !git config --global user.email "hathithuhien07082003@gmail.com"
# !git config --global user.name "Ha-Hien"

# %%
# !git remote set-url origin https://YOUR_TOKEN@github.com/Ha-Hien/DBA.git

# %%
# !git config --global pull.rebase true

# %%
# !git pull origin main
# Out:
# From https://github.com/Ha-Hien/DBA
#  * branch            main       -> FETCH_HEAD
# Successfully rebased and updated refs/heads/main.

# %%
# 1. Copy file mnist_test.csv vào repository DBA
# !cp /content/sample_data/mnist_test.csv /content/DBA/

# 2. Di chuyển vào thư mục DBA
# %cd /content/DBA

# 3. Thêm file vào Git
# !git add mnist_test.csv

# 4. Commit (đảm bảo đã cấu hình git config)
# !git commit -m "Add MNIST test dataset"

# 5. Push
# !git push origin main
# Out:
# /content/DBA
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 2.10 MiB | 2.32 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Ha-Hien/DBA.git
#    ec6e2ff..a60103b  main -> main

# %%
# Import các thư viện cần thiết
from google.colab import drive
import pandas as pd
import os

# Gắn kết Google Drive để truy cập các tệp dữ liệu
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler
from pathlib import Path
import glob
import logging
from tqdm import tqdm
import os
from datetime import datetime

class OHLCProcessor:
    def __init__(self, start_date: str = '2019-08-26', end_date: str = '2024-08-21', log_dir: str = 'logs'):
        self.start_date = pd.to_datetime(start_date).tz_localize(None)
        self.end_date = pd.to_datetime(end_date).tz_localize(None)
        self.scaler = RobustScaler()
        self.log_dir = log_dir

        # Tạo thư mục logs nếu chưa tồn tại
        if not os.path.exists(log_dir):
            os.makedirs(log_dir)

        self._setup_logging()

    def _setup_logging(self):
        """Setup logging với file và console output"""
        # Tạo tên file log với timestamp
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        log_file = os.path.join(self.log_dir, f'processing_log_{timestamp}.txt')

        # Setup file handler
        fh = logging.FileHandler(log_file)
        fh.setLevel(logging.INFO)

        # Setup console handler
        ch = logging.StreamHandler()
        ch.setLevel(logging.INFO)

        # Setup format
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        fh.setFormatter(formatter)
        ch.setFormatter(formatter)

        # Setup logger
        self.logger = logging.getLogger(__name__)
        self.logger.setLevel(logging.INFO)

        # Remove any existing handlers
        self.logger.handlers = []

        # Add handlers
        self.logger.addHandler(fh)
        self.logger.addHandler(ch)

        print(f"Logging setup complete. Processing will be saved to '{log_file}'")
        self.logger.info("Starting OHLC data processing...")
        self.logger.info(f"Date range: {self.start_date} to {self.end_date}")

    def add_candlestick_patterns(self, df: pd.DataFrame) -> pd.DataFrame:
        """Thêm candlestick patterns"""
        try:
            # Doji Pattern
            df['doji'] = (
                (abs(df['Close'] - df['Open']) <= 0.1 * (df['High'] - df['Low']))
            ).astype(int)

            # Hammer Pattern
            df['hammer'] = (
                (df['Close'] > df['Open']) &
                ((df['High'] - df['Low']) > 2 * (df['Close'] - df['Open'])) &
                ((df['Close'] - df['Low']) / (.001 + df['High'] - df['Low']) > 0.6)
            ).astype(int)

            # Bullish Engulfing
            df['bullish_engulfing'] = (
                (df['Close'] > df['Open'].shift(1)) &
                (df['Open'] < df['Close'].shift(1)) &
                (df['Close'] > df['Open'])
            ).astype(int)

            return df
        except Exception as e:
            self.logger.error(f"Error in add_candlestick_patterns: {str(e)}")
            return df

    def add_time_features(self, df: pd.DataFrame) -> pd.DataFrame:
        """Thêm time-based features"""
        try:
            df['day_of_week'] = df['Date'].dt.dayofweek
            df['month'] = df['Date'].dt.month
            df['quarter'] = df['Date'].dt.quarter
            df['is_month_end'] = df['Date'].dt.is_month_end.astype(int)
            df['is_quarter_end'] = df['Date'].dt.is_quarter_end.astype(int)
            return df
        except Exception as e:
            self.logger.error(f"Error in add_time_features: {str(e)}")
            return df

    def add_lag_features(self, df: pd.DataFrame, symbol: str) -> pd.DataFrame:
        """Thêm lagged features"""
        try:
            # Returns và Volume lags
            for lag in [1, 2, 3, 5]:
                df[f'return_lag_{lag}'] = df['daily_return'].shift(lag)
                df[f'volume_lag_{lag}'] = df['volume_ratio'].shift(lag)

            # Rolling statistics
            windows = [5, 10, 20]
            for window in windows:
                df[f'return_mean_{window}d'] = df['daily_return'].rolling(window).mean()
                df[f'return_std_{window}d'] = df['daily_return'].rolling(window).std()
                df[f'momentum_{window}d'] = df['Close'].diff(window)

            return df
        except Exception as e:
            self.logger.error(f"Error in add_lag_features for {symbol}: {str(e)}")
            return df

    def process_single_stock(self, file_path: str) -> pd.DataFrame:
        """Xử lý dữ liệu cho một cổ phiếu với logging chi tiết"""
        try:
            # 1. Đọc dữ liệu
            df = pd.read_csv(file_path)
            symbol = Path(file_path).stem
            self.logger.info(f"\n{'='*50}")
            self.logger.info(f"Processing {symbol}")
            self.logger.info(f"Initial shape: {df.shape}")

            # 2. Convert types
            numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
            for col in numeric_cols:
                df[col] = df[col].astype('float64')
            self.logger.info(f"Converted {len(numeric_cols)} columns to float64")

            # 3. Xử lý datetime và filter
            df['symbol'] = symbol
            df['Date'] = pd.to_datetime(df['Date'], utc=True).dt.tz_localize(None)
            self.logger.info(f"Date range: {df['Date'].min()} to {df['Date'].max()}")

            mask = (df['Date'] >= self.start_date) & (df['Date'] <= self.end_date)
            df = df[mask].copy()
            self.logger.info(f"Shape after date filtering: {df.shape}")

            if len(df) == 0:
                self.logger.warning(f"No data in specified date range for {symbol}")
                return None

            # 4. Add Covid-19 Features
            self.logger.info("\nAdding Covid-19 features...")
            df['is_covid_crash'] = ((df['Date'] >= '2020-02-01') &
                                  (df['Date'] <= '2020-04-30')).astype(int)
            df['is_covid_recovery'] = ((df['Date'] >= '2020-05-01') &
                                      (df['Date'] <= '2020-12-31')).astype(int)
            df['is_post_covid'] = (df['Date'] >= '2021-01-01').astype(int)

            covid_dist = df[['is_covid_crash', 'is_covid_recovery', 'is_post_covid']].sum()
            self.logger.info("Covid period distribution:")
            self.logger.info(f"Crash period: {covid_dist['is_covid_crash']} days")
            self.logger.info(f"Recovery period: {covid_dist['is_covid_recovery']} days")
            self.logger.info(f"Post-covid period: {covid_dist['is_post_covid']} days")

            # 5. Price Features
            self.logger.info("\nCalculating price features...")
            initial_cols = set(df.columns)

            df['daily_return'] = df['Close'].pct_change()
            df['hl_ratio'] = (df['High'] - df['Low']) / df['Low']
            df['co_ratio'] = (df['Close'] - df['Open']) / df['Open']

            price_features = set(df.columns) - initial_cols
            self.logger.info(f"Added {len(price_features)} price features: {price_features}")

            # Log các statistics cơ bản
            self.logger.info("\nPrice feature statistics:")
            self.logger.info(df[['daily_return', 'hl_ratio', 'co_ratio']].describe())

            # 6. Volume Features
            self.logger.info("\nCalculating volume features...")
            initial_cols = set(df.columns)

            df['volume_ratio'] = df['Volume'] / df['Volume'].rolling(5, min_periods=1).mean()
            df['volume_ma5'] = df['Volume'].rolling(window=5, min_periods=1).mean()
            df['volume_ma20'] = df['Volume'].rolling(window=20, min_periods=1).mean()

            volume_features = set(df.columns) - initial_cols
            self.logger.info(f"Added {len(volume_features)} volume features: {volume_features}")

            # 7. Technical Indicators
            self.logger.info("\nCalculating technical indicators...")
            initial_cols = set(df.columns)

            windows = [5, 10, 20]
            for window in windows:
                # Moving Averages
                df[f'sma_{window}'] = df['Close'].rolling(window=window, min_periods=1).mean()
                df[f'ema_{window}'] = df['Close'].ewm(span=window, adjust=False).mean()

                # Volatility
                df[f'volatility_{window}'] = df['daily_return'].rolling(
                    window=window, min_periods=1).std()

                # RSI
                delta = df['Close'].diff()
                gain = delta.where(delta > 0, 0).rolling(window=window, min_periods=1).mean()
                loss = -delta.where(delta < 0, 0).rolling(window=window, min_periods=1).mean()
                rs = gain / loss
                df[f'rsi_{window}'] = 100 - (100 / (1 + rs))

            tech_features = set(df.columns) - initial_cols
            self.logger.info(f"Added {len(tech_features)} technical features: {tech_features}")

            # 8. Candlestick Patterns
            self.logger.info("\nAdding candlestick patterns...")
            initial_cols = set(df.columns)

            df = self.add_candlestick_patterns(df)
            candlestick_features = set(df.columns) - initial_cols
            self.logger.info(f"Added {len(candlestick_features)} candlestick features: {candlestick_features}")

            # Log pattern distribution
            pattern_dist = df[list(candlestick_features)].sum()
            self.logger.info("\nPattern occurrences:")
            self.logger.info(pattern_dist)

            # 9. Time Features
            self.logger.info("\nAdding time features...")
            initial_cols = set(df.columns)

            df = self.add_time_features(df)
            time_features = set(df.columns) - initial_cols
            self.logger.info(f"Added {len(time_features)} time features: {time_features}")

            # 10. Lag Features
            self.logger.info("\nAdding lag features...")
            initial_cols = set(df.columns)

            df = self.add_lag_features(df, symbol)
            lag_features = set(df.columns) - initial_cols
            self.logger.info(f"Added {len(lag_features)} lag features: {lag_features}")

            # 11. Handle Missing Values
            self.logger.info("\nHandling missing values...")
            missing_before = df.isnull().sum().sum()

            numeric_cols = df.select_dtypes(include=['float64']).columns
            for col in numeric_cols:
                df[col] = df[col].ffill(limit=5).bfill(limit=5)

            missing_after = df.isnull().sum().sum()
            self.logger.info(f"Filled {missing_before - missing_after} missing values")

            if missing_after > 0:
                self.logger.warning(f"Remaining missing values: {missing_after}")
                missing_cols = df.columns[df.isnull().any()].tolist()
                self.logger.warning(f"Columns with missing values: {missing_cols}")

            # Final Summary
            self.logger.info(f"\nFinal processing summary for {symbol}:")
            self.logger.info(f"Initial shape: {df.shape}")
            self.logger.info(f"Total features added: {len(df.columns) - len(['Date', 'symbol', 'Open', 'High', 'Low', 'Close', 'Volume'])}")
            self.logger.info(f"Final memory usage: {df.memory_usage().sum() / 1024**2:.2f} MB")

            return df

        except Exception as e:
            self.logger.error(f"Error processing {symbol}: {str(e)}")
            return None

    def normalize_stock_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """Normalize dữ liệu theo từng cổ phiếu và nhóm features"""
        feature_groups = {
            'price': ['Open', 'High', 'Low', 'Close'],
            'volume': ['Volume'] + [col for col in df.columns if 'volume' in col.lower()],
            'momentum': [col for col in df.columns if any(x in col.lower() for x in ['momentum', 'macd'])],
            'volatility': [col for col in df.columns if 'volatility' in col.lower()],
            'oscillators': [col for col in df.columns if any(x in col.lower() for x in ['rsi', 'bb'])],
            'ratios': [col for col in df.columns if 'ratio' in col.lower()]
        }

        normalized_df = df.copy()

        for symbol in df['symbol'].unique():
            try:
                mask = df['symbol'] == symbol
                symbol_data = df[mask].copy()

                for group_name, cols in feature_groups.items():
                    cols_exist = [col for col in cols if col in df.columns]
                    if cols_exist:
                        try:
                            data_to_normalize = symbol_data[cols_exist].astype('float64')
                            if not data_to_normalize.empty and not data_to_normalize.isnull().all().all():
                                normalized_values = self.scaler.fit_transform(data_to_normalize)
                                for col_idx, col in enumerate(cols_exist):
                                    normalized_df.loc[mask, col] = normalized_values[:, col_idx]
                        except Exception as e:
                            self.logger.error(f"Error normalizing {group_name} for {symbol}: {str(e)}")

            except Exception as e:
                self.logger.error(f"Error processing {symbol}: {str(e)}")

        return normalized_df

    def process_all_stocks(self, data_dir: str) -> pd.DataFrame:
        """Xử lý tất cả các file với logging chi tiết"""
        all_files = glob.glob(f"{data_dir}/*.csv")
        self.logger.info(f"\n{'='*50}")
        self.logger.info(f"Starting processing of {len(all_files)} files")

        # Process từng file với progress bar
        all_stocks = []
        total_rows = 0
        total_features = 0

        for file in tqdm(all_files, desc="Processing stocks"):
            df = self.process_single_stock(file)
            if df is not None and not df.empty:
                total_rows += len(df)
                total_features = len(df.columns)
                all_stocks.append(df)

        if not all_stocks:
            raise ValueError("No valid stock data found")

        # Gộp dữ liệu
        self.logger.info(f"\n{'='*50}")
        self.logger.info("Combining processed stocks...")
        combined_df = pd.concat(all_stocks, ignore_index=True)

        self.logger.info("\nCombined data statistics:")
        self.logger.info(f"Total stocks processed: {len(all_stocks)}")
        self.logger.info(f"Total rows: {total_rows}")
        self.logger.info(f"Total features: {total_features}")
        self.logger.info(f"Combined shape: {combined_df.shape}")

        # Normalize
        self.logger.info(f"\n{'='*50}")
        self.logger.info("Starting normalization...")
        normalized_df = self.normalize_stock_data(combined_df)

        self.logger.info("\nNormalization summary:")
        self.logger.info(f"Shape before normalization: {combined_df.shape}")
        self.logger.info(f"Shape after normalization: {normalized_df.shape}")

        # Final cleaning
        self.logger.info(f"\n{'='*50}")
        self.logger.info("Final cleaning...")
        initial_rows = len(normalized_df)
        final_df = normalized_df.dropna()

        self.logger.info("\nFinal statistics:")
        self.logger.info(f"Initial rows: {initial_rows}")
        self.logger.info(f"Final rows: {len(final_df)}")
        self.logger.info(f"Rows removed: {initial_rows - len(final_df)}")
        self.logger.info(f"Final shape: {final_df.shape}")
        self.logger.info(f"Unique symbols: {final_df['symbol'].nunique()}")
        self.logger.info(f"Memory usage: {final_df.memory_usage().sum() / 1024**2:.2f} MB")

        return final_df

# %%
def main():
    # Khởi tạo processor với logging
    processor = OHLCProcessor(
        start_date='2019-08-26',
        end_date='2024-08-21',
        log_dir='ohlc_processing_logs'
    )

    # Xử lý dữ liệu
    input_dir = "/content/drive/MyDrive/DATASET/OHLC/"
    output_file = "/content/drive/MyDrive/DATASET/processed_ohlc_data.csv"

    try:
        # Process data
        processed_data = processor.process_all_stocks(input_dir)

        # Save results
        processed_data.to_csv(output_file, index=False)

        # Log final summary
        processor.logger.info("\nProcessing Complete!")
        processor.logger.info(f"Output file saved to: {output_file}")
        processor.logger.info(f"File size: {round(os.path.getsize(output_file) / (1024*1024), 2)} MB")
        processor.logger.info(f"Total rows: {len(processed_data)}")
        processor.logger.info(f"Total columns: {len(processed_data.columns)}")
        processor.logger.info(f"Memory usage: {processed_data.memory_usage().sum() / 1024**2:.2f} MB")

    except Exception as e:
        processor.logger.error(f"Error in main processing: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# 2024-12-22 10:07:39,017 - INFO - Starting OHLC data processing...
# INFO:__main__:Starting OHLC data processing...
# 2024-12-22 10:07:39,026 - INFO - Date range: 2019-08-26 00:00:00 to 2024-08-21 00:00:00
# INFO:__main__:Date range: 2019-08-26 00:00:00 to 2024-08-21 00:00:00
# 2024-12-22 10:07:39,056 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:07:39,060 - INFO - Starting processing of 502 files
# INFO:__main__:Starting processing of 502 files
# Logging setup complete. Processing will be saved to 'ohlc_processing_logs/processing_log_20241222_100739.txt'
# Streaming output truncated to the last 5000 lines.
# Calculating volume features...
# 2024-12-22 10:11:14,718 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:14,727 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:14,758 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:14,767 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:14,783 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:14,797 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:14,807 - INFO - bullish_engulfing    208
# hammer               206
# doji                 133
# dtype: int64
# INFO:__main__:bullish_engulfing    208
# hammer               206
# doji                 133
# dtype: int64
# 2024-12-22 10:11:14,818 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:14,830 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:14,838 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:14,858 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:14,865 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:14,920 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:14,930 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:14,944 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:14,953 - INFO -
# Final processing summary for AJG:
# INFO:__main__:
# Final processing summary for AJG:
# 2024-12-22 10:11:14,956 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:14,962 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:14,973 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks:  92%|█████████▏| 460/502 [03:35<00:20,  2.09it/s]2024-12-22 10:11:15,012 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:15,015 - INFO - Processing ADM
# INFO:__main__:Processing ADM
# 2024-12-22 10:11:15,025 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:15,037 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:15,092 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:15,104 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:15,111 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:15,129 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:15,145 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:15,148 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:15,155 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:15,160 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:15,175 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:15,191 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:15,231 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000640     0.021898    -0.000009
# std        0.019021     0.012573     0.014732
# min       -0.241971     0.005651    -0.096784
# 25%       -0.007819     0.014431    -0.007527
# 50%        0.001788     0.018711     0.000686
# 75%        0.010094     0.025566     0.008634
# max        0.102695     0.121771     0.060687
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000640     0.021898    -0.000009
# std        0.019021     0.012573     0.014732
# min       -0.241971     0.005651    -0.096784
# 25%       -0.007819     0.014431    -0.007527
# 50%        0.001788     0.018711     0.000686
# 75%        0.010094     0.025566     0.008634
# max        0.102695     0.121771     0.060687
# 2024-12-22 10:11:15,253 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:15,264 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:15,268 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:15,301 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:15,307 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:15,321 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:15,329 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:15,335 - INFO - bullish_engulfing    157
# hammer               218
# doji                 125
# dtype: int64
# INFO:__main__:bullish_engulfing    157
# hammer               218
# doji                 125
# dtype: int64
# 2024-12-22 10:11:15,343 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:15,356 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:15,360 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:15,385 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:15,393 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:15,434 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:15,440 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:15,450 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:15,456 - INFO -
# Final processing summary for ADM:
# INFO:__main__:
# Final processing summary for ADM:
# 2024-12-22 10:11:15,458 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:15,461 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:15,468 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks:  92%|█████████▏| 461/502 [03:36<00:19,  2.07it/s]2024-12-22 10:11:15,493 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:15,497 - INFO - Processing ACGL
# INFO:__main__:Processing ACGL
# 2024-12-22 10:11:15,499 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:15,510 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:15,541 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:15,548 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:15,553 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:15,563 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:15,570 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:15,573 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:15,577 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:15,580 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:15,588 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:15,591 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:15,610 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000996     0.024143     0.000205
# std        0.021052     0.015795     0.017235
# min       -0.168752     0.004790    -0.093884
# 25%       -0.007782     0.014293    -0.009082
# 50%        0.001521     0.019905     0.001394
# 75%        0.011016     0.028930     0.009291
# max        0.153577     0.177830     0.132443
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000996     0.024143     0.000205
# std        0.021052     0.015795     0.017235
# min       -0.168752     0.004790    -0.093884
# 25%       -0.007782     0.014293    -0.009082
# 50%        0.001521     0.019905     0.001394
# 75%        0.011016     0.028930     0.009291
# max        0.153577     0.177830     0.132443
# 2024-12-22 10:11:15,633 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:15,642 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:15,647 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:15,672 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:15,677 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:15,689 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:15,696 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:15,701 - INFO - bullish_engulfing    204
# hammer               196
# doji                 122
# dtype: int64
# INFO:__main__:bullish_engulfing    204
# hammer               196
# doji                 122
# dtype: int64
# 2024-12-22 10:11:15,708 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:15,718 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:15,724 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:15,741 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:15,746 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:15,777 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:15,783 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:15,791 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:15,794 - INFO -
# Final processing summary for ACGL:
# INFO:__main__:
# Final processing summary for ACGL:
# 2024-12-22 10:11:15,798 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:15,800 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:15,807 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks:  92%|█████████▏| 462/502 [03:36<00:17,  2.28it/s]2024-12-22 10:11:15,827 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:15,832 - INFO - Processing AMAT
# INFO:__main__:Processing AMAT
# 2024-12-22 10:11:15,834 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:15,841 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:15,872 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:15,879 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:15,883 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:15,892 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:15,900 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:15,903 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:15,905 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:15,908 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:15,915 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:15,918 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:15,941 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.001668     0.032850     0.000603
# std        0.029173     0.017408     0.022166
# min       -0.203576     0.006565    -0.084358
# 25%       -0.013990     0.021528    -0.012340
# 50%        0.001355     0.028454     0.000000
# 75%        0.017868     0.040563     0.014293
# max        0.128131     0.158411     0.100305
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.001668     0.032850     0.000603
# std        0.029173     0.017408     0.022166
# min       -0.203576     0.006565    -0.084358
# 25%       -0.013990     0.021528    -0.012340
# 50%        0.001355     0.028454     0.000000
# 75%        0.017868     0.040563     0.014293
# max        0.128131     0.158411     0.100305
# 2024-12-22 10:11:15,961 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:15,969 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:15,973 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:16,005 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:16,010 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:16,023 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:16,030 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:16,035 - INFO - bullish_engulfing    160
# hammer               163
# doji                 106
# dtype: int64
# INFO:__main__:bullish_engulfing    160
# hammer               163
# doji                 106
# dtype: int64
# 2024-12-22 10:11:16,043 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:16,052 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:16,058 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:16,077 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:16,082 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:16,122 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:16,126 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:16,135 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:16,140 - INFO -
# Final processing summary for AMAT:
# INFO:__main__:
# Final processing summary for AMAT:
# 2024-12-22 10:11:16,143 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:16,146 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:16,152 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks:  92%|█████████▏| 463/502 [03:37<00:16,  2.43it/s]2024-12-22 10:11:16,177 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:16,182 - INFO - Processing APTV
# INFO:__main__:Processing APTV
# 2024-12-22 10:11:16,185 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:16,192 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:16,221 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:16,230 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:16,235 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:16,252 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:16,259 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:16,262 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:16,264 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:16,267 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:16,273 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:16,275 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:16,289 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000342     0.032832    -0.000353
# std        0.029797     0.027883     0.022755
# min       -0.305527     0.006781    -0.244029
# 25%       -0.014056     0.019881    -0.012650
# 50%        0.000554     0.027567    -0.000213
# 75%        0.015192     0.038923     0.012650
# max        0.209538     0.563997     0.221186
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000342     0.032832    -0.000353
# std        0.029797     0.027883     0.022755
# min       -0.305527     0.006781    -0.244029
# 25%       -0.014056     0.019881    -0.012650
# 50%        0.000554     0.027567    -0.000213
# 75%        0.015192     0.038923     0.012650
# max        0.209538     0.563997     0.221186
# 2024-12-22 10:11:16,316 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:16,324 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:16,328 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:16,359 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:16,364 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:16,375 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:16,384 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:16,389 - INFO - bullish_engulfing    152
# hammer               198
# doji                 108
# dtype: int64
# INFO:__main__:bullish_engulfing    152
# hammer               198
# doji                 108
# dtype: int64
# 2024-12-22 10:11:16,396 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:16,409 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:16,413 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:16,445 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:16,451 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:16,510 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:16,517 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:16,527 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:16,537 - INFO -
# Final processing summary for APTV:
# INFO:__main__:
# Final processing summary for APTV:
# 2024-12-22 10:11:16,545 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:16,548 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:16,563 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks:  92%|█████████▏| 464/502 [03:37<00:15,  2.43it/s]2024-12-22 10:11:16,604 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:16,610 - INFO - Processing AAPL
# INFO:__main__:Processing AAPL
# 2024-12-22 10:11:16,615 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:16,632 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:16,684 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:16,691 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:16,697 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:16,710 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:16,718 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:16,721 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:16,724 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:16,730 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:16,741 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:16,745 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:16,785 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.001406     0.022712     0.001213
# std        0.019992     0.013110     0.015434
# min       -0.128647     0.005411    -0.072579
# 25%       -0.008279     0.014207    -0.006931
# 50%        0.001449     0.019046     0.001152
# 75%        0.012352     0.027587     0.010383
# max        0.119808     0.115520     0.069713
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.001406     0.022712     0.001213
# std        0.019992     0.013110     0.015434
# min       -0.128647     0.005411    -0.072579
# 25%       -0.008279     0.014207    -0.006931
# 50%        0.001449     0.019046     0.001152
# 75%        0.012352     0.027587     0.010383
# max        0.119808     0.115520     0.069713
# 2024-12-22 10:11:16,819 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:16,835 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:16,842 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:16,885 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:16,893 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:16,911 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:16,925 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:16,932 - INFO - bullish_engulfing    186
# hammer               183
# doji                 123
# dtype: int64
# INFO:__main__:bullish_engulfing    186
# hammer               183
# doji                 123
# dtype: int64
# 2024-12-22 10:11:16,939 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:16,956 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:16,963 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:16,990 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:16,998 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:17,060 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:17,064 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:17,074 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:17,083 - INFO -
# Final processing summary for AAPL:
# INFO:__main__:
# Final processing summary for AAPL:
# 2024-12-22 10:11:17,091 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:17,093 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:17,101 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks:  93%|█████████▎| 465/502 [03:38<00:16,  2.22it/s]2024-12-22 10:11:17,130 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:17,134 - INFO - Processing APA
# INFO:__main__:Processing APA
# 2024-12-22 10:11:17,139 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:17,148 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:17,195 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:17,206 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:17,212 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:17,231 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:17,238 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:17,243 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:17,246 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:17,253 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:17,264 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:17,270 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:17,313 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.001390     0.049437    -0.000488
# std        0.044808     0.037096     0.034538
# min       -0.538647     0.011711    -0.288376
# 25%       -0.019627     0.028844    -0.016726
# 50%        0.000995     0.040475    -0.000830
# 75%        0.019934     0.057270     0.016382
# max        0.294664     0.469957     0.160083
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.001390     0.049437    -0.000488
# std        0.044808     0.037096     0.034538
# min       -0.538647     0.011711    -0.288376
# 25%       -0.019627     0.028844    -0.016726
# 50%        0.000995     0.040475    -0.000830
# 75%        0.019934     0.057270     0.016382
# max        0.294664     0.469957     0.160083
# 2024-12-22 10:11:17,340 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:17,356 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:17,363 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:17,407 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:17,419 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:17,436 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:17,447 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:17,456 - INFO - bullish_engulfing    144
# hammer               190
# doji                 137
# dtype: int64
# INFO:__main__:bullish_engulfing    144
# hammer               190
# doji                 137
# dtype: int64
# 2024-12-22 10:11:17,468 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:17,487 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:17,496 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:17,525 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:17,530 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:17,583 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:17,594 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:17,604 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:17,613 - INFO -
# Final processing summary for APA:
# INFO:__main__:
# Final processing summary for APA:
# 2024-12-22 10:11:17,619 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:17,626 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:17,635 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks:  93%|█████████▎| 466/502 [03:38<00:17,  2.11it/s]2024-12-22 10:11:17,668 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:17,670 - INFO - Processing AON
# INFO:__main__:Processing AON
# 2024-12-22 10:11:17,674 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:17,684 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:17,728 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:17,739 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:17,745 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:17,757 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:17,767 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:17,770 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:17,772 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:17,775 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:17,784 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:17,789 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:17,817 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000627     0.020749     0.000507
# std        0.016978     0.013440     0.014405
# min       -0.167031     0.004378    -0.098090
# 25%       -0.007299     0.012935    -0.006604
# 50%        0.000841     0.017452     0.000755
# 75%        0.008508     0.023962     0.007335
# max        0.141326     0.144266     0.102011
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000627     0.020749     0.000507
# std        0.016978     0.013440     0.014405
# min       -0.167031     0.004378    -0.098090
# 25%       -0.007299     0.012935    -0.006604
# 50%        0.000841     0.017452     0.000755
# 75%        0.008508     0.023962     0.007335
# max        0.141326     0.144266     0.102011
# 2024-12-22 10:11:17,847 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:17,860 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:17,869 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:17,907 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:17,916 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:17,936 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:17,950 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:17,959 - INFO - bullish_engulfing    183
# hammer               222
# doji                 121
# dtype: int64
# INFO:__main__:bullish_engulfing    183
# hammer               222
# doji                 121
# dtype: int64
# 2024-12-22 10:11:17,970 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:17,988 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:17,998 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:18,028 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:18,037 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:18,081 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:18,086 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:18,094 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:18,098 - INFO -
# Final processing summary for AON:
# INFO:__main__:
# Final processing summary for AON:
# 2024-12-22 10:11:18,102 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:18,104 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:18,117 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks:  93%|█████████▎| 467/502 [03:39<00:16,  2.10it/s]2024-12-22 10:11:18,151 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:18,156 - INFO - Processing ANSS
# INFO:__main__:Processing ANSS
# 2024-12-22 10:11:18,162 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:18,175 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:18,212 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:18,223 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:18,229 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# ...
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:33,342 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:33,347 - INFO -
# Final processing summary for ABT:
# INFO:__main__:
# Final processing summary for ABT:
# 2024-12-22 10:11:33,352 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:33,357 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:33,366 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks: 100%|█████████▉| 500/502 [03:54<00:00,  2.10it/s]2024-12-22 10:11:33,386 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:33,392 - INFO - Processing AOS
# INFO:__main__:Processing AOS
# 2024-12-22 10:11:33,395 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:33,401 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:33,429 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:33,436 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:33,440 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:33,449 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:33,455 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:33,458 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:33,460 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:33,463 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:33,469 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:33,472 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:33,498 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000717     0.023733     0.000209
# std        0.019080     0.012650     0.015403
# min       -0.093908     0.007061    -0.073068
# 25%       -0.009753     0.015382    -0.008505
# 50%        0.000868     0.020746     0.000147
# 75%        0.011153     0.028163     0.008702
# max        0.136669     0.134886     0.058143
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000717     0.023733     0.000209
# std        0.019080     0.012650     0.015403
# min       -0.093908     0.007061    -0.073068
# 25%       -0.009753     0.015382    -0.008505
# 50%        0.000868     0.020746     0.000147
# 75%        0.011153     0.028163     0.008702
# max        0.136669     0.134886     0.058143
# 2024-12-22 10:11:33,511 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:33,519 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:33,524 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:33,549 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:33,554 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:33,565 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:33,572 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:33,576 - INFO - bullish_engulfing    142
# hammer               198
# doji                 137
# dtype: int64
# INFO:__main__:bullish_engulfing    142
# hammer               198
# doji                 137
# dtype: int64
# 2024-12-22 10:11:33,582 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:33,591 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:33,596 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:33,613 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:33,618 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:33,652 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:33,657 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:33,665 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:33,671 - INFO -
# Final processing summary for AOS:
# INFO:__main__:
# Final processing summary for AOS:
# 2024-12-22 10:11:33,676 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:33,679 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:33,688 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks: 100%|█████████▉| 501/502 [03:54<00:00,  2.33it/s]2024-12-22 10:11:33,713 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:33,717 - INFO - Processing MMM
# INFO:__main__:Processing MMM
# 2024-12-22 10:11:33,722 - INFO - Initial shape: (1256, 8)
# INFO:__main__:Initial shape: (1256, 8)
# 2024-12-22 10:11:33,732 - INFO - Converted 7 columns to float64
# INFO:__main__:Converted 7 columns to float64
# 2024-12-22 10:11:33,769 - INFO - Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# INFO:__main__:Date range: 2019-08-26 04:00:00 to 2024-08-21 04:00:00
# 2024-12-22 10:11:33,779 - INFO - Shape after date filtering: (1255, 9)
# INFO:__main__:Shape after date filtering: (1255, 9)
# 2024-12-22 10:11:33,783 - INFO -
# Adding Covid-19 features...
# INFO:__main__:
# Adding Covid-19 features...
# 2024-12-22 10:11:33,797 - INFO - Covid period distribution:
# INFO:__main__:Covid period distribution:
# 2024-12-22 10:11:33,805 - INFO - Crash period: 61 days
# INFO:__main__:Crash period: 61 days
# 2024-12-22 10:11:33,812 - INFO - Recovery period: 169 days
# INFO:__main__:Recovery period: 169 days
# 2024-12-22 10:11:33,815 - INFO - Post-covid period: 913 days
# INFO:__main__:Post-covid period: 913 days
# 2024-12-22 10:11:33,817 - INFO -
# Calculating price features...
# INFO:__main__:
# Calculating price features...
# 2024-12-22 10:11:33,824 - INFO - Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# INFO:__main__:Added 3 price features: {'hl_ratio', 'daily_return', 'co_ratio'}
# 2024-12-22 10:11:33,826 - INFO -
# Price feature statistics:
# INFO:__main__:
# Price feature statistics:
# 2024-12-22 10:11:33,848 - INFO -        daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000314     0.020813    -0.000382
# std        0.018664     0.012449     0.014759
# min       -0.110350     0.006262    -0.100947
# 25%       -0.008526     0.013556    -0.007983
# 50%        0.000104     0.017989    -0.000375
# 75%        0.008674     0.023793     0.007245
# max        0.229906     0.136126     0.128405
# INFO:__main__:       daily_return     hl_ratio     co_ratio
# count   1254.000000  1255.000000  1255.000000
# mean       0.000314     0.020813    -0.000382
# std        0.018664     0.012449     0.014759
# min       -0.110350     0.006262    -0.100947
# 25%       -0.008526     0.013556    -0.007983
# 50%        0.000104     0.017989    -0.000375
# 75%        0.008674     0.023793     0.007245
# max        0.229906     0.136126     0.128405
# 2024-12-22 10:11:33,863 - INFO -
# Calculating volume features...
# INFO:__main__:
# Calculating volume features...
# 2024-12-22 10:11:33,872 - INFO - Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# INFO:__main__:Added 3 volume features: {'volume_ma20', 'volume_ratio', 'volume_ma5'}
# 2024-12-22 10:11:33,876 - INFO -
# Calculating technical indicators...
# INFO:__main__:
# Calculating technical indicators...
# 2024-12-22 10:11:33,904 - INFO - Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# INFO:__main__:Added 12 technical features: {'volatility_10', 'sma_5', 'volatility_5', 'sma_20', 'ema_5', 'sma_10', 'rsi_20', 'ema_20', 'ema_10', 'volatility_20', 'rsi_5', 'rsi_10'}
# 2024-12-22 10:11:33,909 - INFO -
# Adding candlestick patterns...
# INFO:__main__:
# Adding candlestick patterns...
# 2024-12-22 10:11:33,920 - INFO - Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# INFO:__main__:Added 3 candlestick features: {'bullish_engulfing', 'hammer', 'doji'}
# 2024-12-22 10:11:33,933 - INFO -
# Pattern occurrences:
# INFO:__main__:
# Pattern occurrences:
# 2024-12-22 10:11:33,944 - INFO - bullish_engulfing    168
# hammer               216
# doji                 112
# dtype: int64
# INFO:__main__:bullish_engulfing    168
# hammer               216
# doji                 112
# dtype: int64
# 2024-12-22 10:11:33,952 - INFO -
# Adding time features...
# INFO:__main__:
# Adding time features...
# 2024-12-22 10:11:33,960 - INFO - Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# INFO:__main__:Added 5 time features: {'is_month_end', 'quarter', 'day_of_week', 'is_quarter_end', 'month'}
# 2024-12-22 10:11:33,967 - INFO -
# Adding lag features...
# INFO:__main__:
# Adding lag features...
# 2024-12-22 10:11:33,987 - INFO - Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# INFO:__main__:Added 17 lag features: {'momentum_5d', 'return_lag_3', 'volume_lag_5', 'momentum_10d', 'return_lag_2', 'volume_lag_3', 'return_std_20d', 'momentum_20d', 'return_lag_5', 'return_std_5d', 'return_mean_10d', 'return_std_10d', 'volume_lag_2', 'return_lag_1', 'volume_lag_1', 'return_mean_5d', 'return_mean_20d'}
# 2024-12-22 10:11:33,998 - INFO -
# Handling missing values...
# INFO:__main__:
# Handling missing values...
# 2024-12-22 10:11:34,067 - INFO - Filled 80 missing values
# INFO:__main__:Filled 80 missing values
# 2024-12-22 10:11:34,078 - WARNING - Remaining missing values: 61
# WARNING:__main__:Remaining missing values: 61
# 2024-12-22 10:11:34,089 - WARNING - Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# WARNING:__main__:Columns with missing values: ['return_lag_5', 'return_mean_10d', 'return_std_10d', 'momentum_10d', 'return_mean_20d', 'return_std_20d', 'momentum_20d']
# 2024-12-22 10:11:34,100 - INFO -
# Final processing summary for MMM:
# INFO:__main__:
# Final processing summary for MMM:
# 2024-12-22 10:11:34,103 - INFO - Initial shape: (1255, 55)
# INFO:__main__:Initial shape: (1255, 55)
# 2024-12-22 10:11:34,110 - INFO - Total features added: 48
# INFO:__main__:Total features added: 48
# 2024-12-22 10:11:34,127 - INFO - Final memory usage: 0.52 MB
# INFO:__main__:Final memory usage: 0.52 MB
# Processing stocks: 100%|██████████| 502/502 [03:55<00:00,  2.14it/s]
# 2024-12-22 10:11:34,137 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:34,144 - INFO - Combining processed stocks...
# INFO:__main__:Combining processed stocks...
# 2024-12-22 10:11:35,050 - INFO -
# Combined data statistics:
# INFO:__main__:
# Combined data statistics:
# 2024-12-22 10:11:35,055 - INFO - Total stocks processed: 502
# INFO:__main__:Total stocks processed: 502
# 2024-12-22 10:11:35,061 - INFO - Total rows: 623653
# INFO:__main__:Total rows: 623653
# 2024-12-22 10:11:35,066 - INFO - Total features: 55
# INFO:__main__:Total features: 55
# 2024-12-22 10:11:35,072 - INFO - Combined shape: (623653, 55)
# INFO:__main__:Combined shape: (623653, 55)
# 2024-12-22 10:11:35,077 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:11:35,081 - INFO - Starting normalization...
# INFO:__main__:Starting normalization...
# 2024-12-22 10:13:15,936 - INFO -
# Normalization summary:
# INFO:__main__:
# Normalization summary:
# 2024-12-22 10:13:15,941 - INFO - Shape before normalization: (623653, 55)
# INFO:__main__:Shape before normalization: (623653, 55)
# 2024-12-22 10:13:15,945 - INFO - Shape after normalization: (623653, 55)
# INFO:__main__:Shape after normalization: (623653, 55)
# 2024-12-22 10:13:15,948 - INFO -
# ==================================================
# INFO:__main__:
# ==================================================
# 2024-12-22 10:13:15,956 - INFO - Final cleaning...
# INFO:__main__:Final cleaning...
# 2024-12-22 10:13:16,282 - INFO -
# Final statistics:
# INFO:__main__:
# Final statistics:
# 2024-12-22 10:13:16,293 - INFO - Initial rows: 623653
# INFO:__main__:Initial rows: 623653
# 2024-12-22 10:13:16,301 - INFO - Final rows: 616123
# INFO:__main__:Final rows: 616123
# 2024-12-22 10:13:16,304 - INFO - Rows removed: 7530
# INFO:__main__:Rows removed: 7530
# 2024-12-22 10:13:16,307 - INFO - Final shape: (616123, 55)
# INFO:__main__:Final shape: (616123, 55)
# 2024-12-22 10:13:16,368 - INFO - Unique symbols: 502
# INFO:__main__:Unique symbols: 502
# 2024-12-22 10:13:16,380 - INFO - Memory usage: 256.19 MB
# INFO:__main__:Memory usage: 256.19 MB
# 2024-12-22 10:14:51,929 - INFO -
# Processing Complete!
# INFO:__main__:
# Processing Complete!
# 2024-12-22 10:14:51,951 - INFO - Output file saved to: /content/drive/MyDrive/DATASET/processed_ohlc_data.csv
# INFO:__main__:Output file saved to: /content/drive/MyDrive/DATASET/processed_ohlc_data.csv
# 2024-12-22 10:14:51,995 - INFO - File size: 501.07 MB
# INFO:__main__:File size: 501.07 MB
# 2024-12-22 10:14:51,999 - INFO - Total rows: 616123
# INFO:__main__:Total rows: 616123
# 2024-12-22 10:14:52,004 - INFO - Total columns: 55
# INFO:__main__:Total columns: 55
# 2024-12-22 10:14:52,027 - INFO - Memory usage: 256.19 MB
# INFO:__main__:Memory usage: 256.19 MB
